# %% [markdown]
# <a href="https://colab.research.google.com/github/SefaSAHAN/Credit_Score_Predict_ML_Project/blob/main/Credit_score_classification_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  
import pandas as pd 
from google.colab import files 
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# url_train = 'https://raw.githubusercontent.com/RamaNahawandi/Credit-score-classification/main/train.csv'
# train_data = pd.read_csv(url_train)

# url_test = 'https://raw.githubusercontent.com/RamaNahawandi/Credit-score-classification/main/test.csv'
# test_data = pd.read_csv(url_test)

# frames = [train_data, test_data]
# df_concat = pd.concat(frames,ignore_index=True)
# Out:
# <ipython-input-4-cc154f57de33>:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_csv(url_train)

# %%
# from google.colab import files
# df_concat.to_csv('full_data.csv', encoding = 'utf-8-sig') 
# files.download('full_data.csv')

# %%
url_full_data = 'https://raw.githubusercontent.com/RamaNahawandi/Credit-score-classification/main/full_data.csv'
DF = pd.read_csv(url_full_data)
# Out:
# <ipython-input-205-a6e5a0bb3d0f>:2: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   DF = pd.read_csv(url_full_data)

# %%
pd.set_option('display.max_columns', None)
# train_data.head(n = 10)
DF
# Out:
#         Unnamed: 0       ID Customer_ID      Month            Name   Age  \
# 0                0   0x1602   CUS_0xd40    January   Aaron Maashoh    23
# 1                1   0x1603   CUS_0xd40   February   Aaron Maashoh    23
# 2                2   0x1604   CUS_0xd40      March   Aaron Maashoh  -500
# 3                3   0x1605   CUS_0xd40      April   Aaron Maashoh    23
# 4                4   0x1606   CUS_0xd40        May   Aaron Maashoh    23
# ...            ...      ...         ...        ...             ...   ...
# 149995      149995  0x25fe5  CUS_0x8600   December  Sarah McBridec  4975
# 149996      149996  0x25fee  CUS_0x942c  September           Nicks    25
# 149997      149997  0x25fef  CUS_0x942c    October           Nicks    25
# 149998      149998  0x25ff0  CUS_0x942c   November           Nicks    25
# 149999      149999  0x25ff1  CUS_0x942c   December           Nicks    25
#
#                 SSN Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0       821-00-0265  Scientist      19114.12            1824.843333
# 1       821-00-0265  Scientist      19114.12                    NaN
# 2       821-00-0265  Scientist      19114.12                    NaN
# 3       821-00-0265  Scientist      19114.12                    NaN
# 4       821-00-0265  Scientist      19114.12            1824.843333
# ...             ...        ...           ...                    ...
# 149995  031-35-0942  Architect      20002.88            1929.906667
# 149996  078-73-5990   Mechanic      39628.99                    NaN
# 149997  078-73-5990   Mechanic      39628.99            3359.415833
# 149998  078-73-5990   Mechanic      39628.99                    NaN
# 149999  078-73-5990   Mechanic      39628.99            3359.415833
#
#         Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                       3                4              3           4
# 1                       3                4              3           4
# 2                       3                4              3           4
# 3                       3                4              3           4
# 4                       3                4              3           4
# ...                   ...              ...            ...         ...
# 149995                 10                8             29           5
# 149996                  4                6              7          2_
# 149997                  4                6              7           2
# 149998                  4                6              7          2_
# 149999                  4                6              7           2
#
#                                              Type_of_Loan  \
# 0       Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1       Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2       Auto Loan, Credit-Builder Loan, Personal Loan,...
# 3       Auto Loan, Credit-Builder Loan, Personal Loan,...
# 4       Auto Loan, Credit-Builder Loan, Personal Loan,...
# ...                                                   ...
# 149995  Personal Loan, Auto Loan, Mortgage Loan, Stude...
# 149996                        Auto Loan, and Student Loan
# 149997                        Auto Loan, and Student Loan
# 149998                        Auto Loan, and Student Loan
# 149999                        Auto Loan, and Student Loan
#
#         Delay_from_due_date Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                         3                      7                11.27
# 1                        -1                    NaN                11.27
# 2                         3                      7                    _
# 3                         5                      4                 6.27
# 4                         6                    NaN                11.27
# ...                     ...                    ...                  ...
# 149995                   33                     25                18.31
# 149996                   20                    NaN                 11.5
# 149997                   23                      5                 13.5
# 149998                   21                     6_                 11.5
# 149999                   22                      5                 11.5
#
#         Num_Credit_Inquiries Credit_Mix Outstanding_Debt  \
# 0                        4.0          _           809.98
# 1                        4.0       Good           809.98
# 2                        4.0       Good           809.98
# 3                        4.0       Good           809.98
# 4                        4.0       Good           809.98
# ...                      ...        ...              ...
# 149995                  12.0          _           3571.7
# 149996                   7.0       Good           502.38
# 149997                   7.0       Good           502.38
# 149998                   7.0       Good           502.38
# 149999                   7.0          _           502.38
#
#         Credit_Utilization_Ratio      Credit_History_Age  \
# 0                      26.822620   22 Years and 1 Months
# 1                      31.944960                     NaN
# 2                      28.609352   22 Years and 3 Months
# 3                      31.377862   22 Years and 4 Months
# 4                      24.797347   22 Years and 5 Months
# ...                          ...                     ...
# 149995                 34.780553                     NaN
# 149996                 27.758522  31 Years and 11 Months
# 149997                 36.858542   32 Years and 0 Months
# 149998                 39.139840   32 Years and 1 Months
# 149999                 34.108530   32 Years and 2 Months
#
#        Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 0                         No            49.574949       80.41529543900253
# 1                         No            49.574949      118.28022162236736
# 2                         No            49.574949         81.699521264648
# 3                         No            49.574949       199.4580743910713
# 4                         No            49.574949      41.420153086217326
# ...                      ...                  ...                     ...
# 149995                   Yes            60.964772      146.48632477751087
# 149996                    NM            35.104023      181.44299902757518
# 149997                    No            35.104023               __10000__
# 149998                    No            35.104023       97.59857973344877
# 149999                    No            35.104023      220.45787812168732
#
#                        Payment_Behaviour     Monthly_Balance Credit_Score
# 0        High_spent_Small_value_payments  312.49408867943663         Good
# 1         Low_spent_Large_value_payments  284.62916249607184         Good
# 2        Low_spent_Medium_value_payments   331.2098628537912         Good
# 3         Low_spent_Small_value_payments  223.45130972736786         Good
# 4       High_spent_Medium_value_payments  341.48923103222177         Good
# ...                                  ...                 ...          ...
# 149995    Low_spent_Small_value_payments  275.53956951573343          NaN
# 149996    Low_spent_Small_value_payments  409.39456169535066          NaN
# 149997    Low_spent_Large_value_payments   349.7263321025098          NaN
# 149998   High_spent_Small_value_payments  463.23898098947717          NaN
# 149999   Low_spent_Medium_value_payments  360.37968260123847          NaN
#
# [150000 rows x 29 columns]

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                150000 non-null  int64
#  1   ID                        150000 non-null  object
#  2   Customer_ID               150000 non-null  object
#  3   Month                     150000 non-null  object
#  4   Name                      135000 non-null  object
#  5   Age                       150000 non-null  object
#  6   SSN                       150000 non-null  object
#  7   Occupation                150000 non-null  object
#  8   Annual_Income             150000 non-null  object
#  9   Monthly_Inhand_Salary     127500 non-null  float64
#  10  Num_Bank_Accounts         150000 non-null  int64
#  11  Num_Credit_Card           150000 non-null  int64
#  12  Interest_Rate             150000 non-null  int64
#  13  Num_of_Loan               150000 non-null  object
#  14  Type_of_Loan              132888 non-null  object
#  15  Delay_from_due_date       150000 non-null  int64
#  16  Num_of_Delayed_Payment    139500 non-null  object
#  17  Changed_Credit_Limit      150000 non-null  object
#  18  Num_Credit_Inquiries      147000 non-null  float64
#  19  Credit_Mix                150000 non-null  object
#  20  Outstanding_Debt          150000 non-null  object
#  21  Credit_Utilization_Ratio  150000 non-null  float64
#  22  Credit_History_Age        136500 non-null  object
#  23  Payment_of_Min_Amount     150000 non-null  object
#  24  Total_EMI_per_month       150000 non-null  float64
#  25  Amount_invested_monthly   143250 non-null  object
#  26  Payment_Behaviour         150000 non-null  object
#  27  Monthly_Balance           148238 non-null  object
#  28  Credit_Score              100000 non-null  object
# dtypes: float64(4), int64(5), object(20)
# memory usage: 33.2+ MB

# %%
df_full = DF.copy()
df_full
# Out:
#         Unnamed: 0       ID Customer_ID      Month            Name   Age  \
# 0                0   0x1602   CUS_0xd40    January   Aaron Maashoh    23
# 1                1   0x1603   CUS_0xd40   February   Aaron Maashoh    23
# 2                2   0x1604   CUS_0xd40      March   Aaron Maashoh  -500
# 3                3   0x1605   CUS_0xd40      April   Aaron Maashoh    23
# 4                4   0x1606   CUS_0xd40        May   Aaron Maashoh    23
# ...            ...      ...         ...        ...             ...   ...
# 149995      149995  0x25fe5  CUS_0x8600   December  Sarah McBridec  4975
# 149996      149996  0x25fee  CUS_0x942c  September           Nicks    25
# 149997      149997  0x25fef  CUS_0x942c    October           Nicks    25
# 149998      149998  0x25ff0  CUS_0x942c   November           Nicks    25
# 149999      149999  0x25ff1  CUS_0x942c   December           Nicks    25
#
#                 SSN Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0       821-00-0265  Scientist      19114.12            1824.843333
# 1       821-00-0265  Scientist      19114.12                    NaN
# 2       821-00-0265  Scientist      19114.12                    NaN
# 3       821-00-0265  Scientist      19114.12                    NaN
# 4       821-00-0265  Scientist      19114.12            1824.843333
# ...             ...        ...           ...                    ...
# 149995  031-35-0942  Architect      20002.88            1929.906667
# 149996  078-73-5990   Mechanic      39628.99                    NaN
# 149997  078-73-5990   Mechanic      39628.99            3359.415833
# 149998  078-73-5990   Mechanic      39628.99                    NaN
# 149999  078-73-5990   Mechanic      39628.99            3359.415833
#
#         Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                       3                4              3           4
# 1                       3                4              3           4
# 2                       3                4              3           4
# 3                       3                4              3           4
# 4                       3                4              3           4
# ...                   ...              ...            ...         ...
# 149995                 10                8             29           5
# 149996                  4                6              7          2_
# 149997                  4                6              7           2
# 149998                  4                6              7          2_
# 149999                  4                6              7           2
#
#                                              Type_of_Loan  \
# 0       Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1       Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2       Auto Loan, Credit-Builder Loan, Personal Loan,...
# 3       Auto Loan, Credit-Builder Loan, Personal Loan,...
# 4       Auto Loan, Credit-Builder Loan, Personal Loan,...
# ...                                                   ...
# 149995  Personal Loan, Auto Loan, Mortgage Loan, Stude...
# 149996                        Auto Loan, and Student Loan
# 149997                        Auto Loan, and Student Loan
# 149998                        Auto Loan, and Student Loan
# 149999                        Auto Loan, and Student Loan
#
#         Delay_from_due_date Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                         3                      7                11.27
# 1                        -1                    NaN                11.27
# 2                         3                      7                    _
# 3                         5                      4                 6.27
# 4                         6                    NaN                11.27
# ...                     ...                    ...                  ...
# 149995                   33                     25                18.31
# 149996                   20                    NaN                 11.5
# 149997                   23                      5                 13.5
# 149998                   21                     6_                 11.5
# 149999                   22                      5                 11.5
#
#         Num_Credit_Inquiries Credit_Mix Outstanding_Debt  \
# 0                        4.0          _           809.98
# 1                        4.0       Good           809.98
# 2                        4.0       Good           809.98
# 3                        4.0       Good           809.98
# 4                        4.0       Good           809.98
# ...                      ...        ...              ...
# 149995                  12.0          _           3571.7
# 149996                   7.0       Good           502.38
# 149997                   7.0       Good           502.38
# 149998                   7.0       Good           502.38
# 149999                   7.0          _           502.38
#
#         Credit_Utilization_Ratio      Credit_History_Age  \
# 0                      26.822620   22 Years and 1 Months
# 1                      31.944960                     NaN
# 2                      28.609352   22 Years and 3 Months
# 3                      31.377862   22 Years and 4 Months
# 4                      24.797347   22 Years and 5 Months
# ...                          ...                     ...
# 149995                 34.780553                     NaN
# 149996                 27.758522  31 Years and 11 Months
# 149997                 36.858542   32 Years and 0 Months
# 149998                 39.139840   32 Years and 1 Months
# 149999                 34.108530   32 Years and 2 Months
#
#        Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 0                         No            49.574949       80.41529543900253
# 1                         No            49.574949      118.28022162236736
# 2                         No            49.574949         81.699521264648
# 3                         No            49.574949       199.4580743910713
# 4                         No            49.574949      41.420153086217326
# ...                      ...                  ...                     ...
# 149995                   Yes            60.964772      146.48632477751087
# 149996                    NM            35.104023      181.44299902757518
# 149997                    No            35.104023               __10000__
# 149998                    No            35.104023       97.59857973344877
# 149999                    No            35.104023      220.45787812168732
#
#                        Payment_Behaviour     Monthly_Balance Credit_Score
# 0        High_spent_Small_value_payments  312.49408867943663         Good
# 1         Low_spent_Large_value_payments  284.62916249607184         Good
# 2        Low_spent_Medium_value_payments   331.2098628537912         Good
# 3         Low_spent_Small_value_payments  223.45130972736786         Good
# 4       High_spent_Medium_value_payments  341.48923103222177         Good
# ...                                  ...                 ...          ...
# 149995    Low_spent_Small_value_payments  275.53956951573343          NaN
# 149996    Low_spent_Small_value_payments  409.39456169535066          NaN
# 149997    Low_spent_Large_value_payments   349.7263321025098          NaN
# 149998   High_spent_Small_value_payments  463.23898098947717          NaN
# 149999   Low_spent_Medium_value_payments  360.37968260123847          NaN
#
# [150000 rows x 29 columns]

# %%
df_full.describe()
# Out:
#           Unnamed: 0  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  150000.000000          127500.000000      150000.000000
# mean    74999.500000            4190.115139          17.006940
# std     43301.414527            3180.489657         117.069476
# min         0.000000             303.645417          -1.000000
# 25%     37499.750000            1625.265833           3.000000
# 50%     74999.500000            3091.000000           6.000000
# 75%    112499.250000            5948.454596           7.000000
# max    149999.000000           15204.633333        1798.000000
#
#        Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# count    150000.000000  150000.000000        150000.000000
# mean         22.623447      71.234907            21.063400
# std         129.143006     461.537193            14.860154
# min           0.000000       1.000000            -5.000000
# 25%           4.000000       8.000000            10.000000
# 50%           5.000000      13.000000            18.000000
# 75%           7.000000      20.000000            28.000000
# max        1499.000000    5799.000000            67.000000
#
#        Num_Credit_Inquiries  Credit_Utilization_Ratio  Total_EMI_per_month
# count         147000.000000             150000.000000        150000.000000
# mean              28.529014                 32.283309          1432.513579
# std              194.456058                  5.113315          8403.759977
# min                0.000000                 20.000000             0.000000
# 25%                3.000000                 28.054731            30.947775
# 50%                6.000000                 32.297058            71.280006
# 75%                9.000000                 36.487954           166.279555
# max             2597.000000                 50.000000         82398.000000

# %%
df_full.shape
# Out:
# (150000, 29)

# %% [markdown]
# we have 8 columns where null values exsit and we need to check

# %%
df_full = df_full.drop(columns=['Unnamed: 0', 'ID', 'Name', 'SSN'])

# %%
df_full.shape
# Out:
# (150000, 25)

# %%
df_full.isnull().sum()
# Out:
# Customer_ID                     0
# Month                           0
# Age                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       22500
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                17112
# Delay_from_due_date             0
# Num_of_Delayed_Payment      10500
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         3000
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age          13500
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      6750
# Payment_Behaviour               0
# Monthly_Balance              1762
# Credit_Score                50000
# dtype: int64

# %%
df_full.isna().sum()
# Out:
# Customer_ID                     0
# Month                           0
# Age                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       22500
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                17112
# Delay_from_due_date             0
# Num_of_Delayed_Payment      10500
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         3000
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age          13500
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      6750
# Payment_Behaviour               0
# Monthly_Balance              1762
# Credit_Score                50000
# dtype: int64

# %% [markdown]
# check how many unique value we have in each column

# %%
DF.nunique()
# Out:
# Unnamed: 0                  150000
# ID                          150000
# Customer_ID                  12500
# Month                           12
# Name                         10139
# Age                           2524
# SSN                          12501
# Occupation                      16
# Annual_Income                21192
# Monthly_Inhand_Salary        13683
# Num_Bank_Accounts             1183
# Num_Credit_Card               1344
# Interest_Rate                 2394
# Num_of_Loan                    623
# Type_of_Loan                  6260
# Delay_from_due_date             73
# Num_of_Delayed_Payment        1058
# Changed_Credit_Limit          4605
# Num_Credit_Inquiries          1607
# Credit_Mix                       4
# Outstanding_Debt             13622
# Credit_Utilization_Ratio    150000
# Credit_History_Age             408
# Payment_of_Min_Amount            3
# Total_EMI_per_month          16960
# Amount_invested_monthly     136497
# Payment_Behaviour                7
# Monthly_Balance             148224
# Credit_Score                     3
# dtype: int64

# %% [markdown]
# we have 12500 customers

# %%
display(    df_full.describe(exclude=np.number).T )
# Out:
#                           count  unique                               top  \
# Customer_ID              150000   12500                         CUS_0xd40
# Month                    150000      12                           January
# Age                      150000    2524                                39
# Occupation               150000      16                           _______
# Annual_Income            150000   21192                          36585.12
# Num_of_Loan              150000     623                                 3
# Type_of_Loan             132888    6260                     Not Specified
# Num_of_Delayed_Payment   139500    1058                                19
# Changed_Credit_Limit     150000    4605                                 _
# Credit_Mix               150000       4                          Standard
# Outstanding_Debt         150000   13622                           1360.45
# Credit_History_Age       136500     408            17 Years and 11 Months
# Payment_of_Min_Amount    150000       3                               Yes
# Amount_invested_monthly  143250  136497                         __10000__
# Payment_Behaviour        150000       7    Low_spent_Small_value_payments
# Monthly_Balance          148238  148224  __-333333333333333333333333333__
# Credit_Score             100000       3                          Standard
#
#                           freq
# Customer_ID                 12
# Month                    12500
# Age                       4198
# Occupation               10500
# Annual_Income               24
# Num_of_Loan              21500
# Type_of_Loan              2112
# Num_of_Delayed_Payment    7949
# Changed_Credit_Limit      3150
# Credit_Mix               54858
# Outstanding_Debt            36
# Credit_History_Age         628
# Payment_of_Min_Amount    78484
# Amount_invested_monthly   6480
# Payment_Behaviour        38207
# Monthly_Balance             15
# Credit_Score             53174

# %%
display(    df_full.describe().T)
# Out:
#                              count         mean          std         min  \
# Monthly_Inhand_Salary     127500.0  4190.115139  3180.489657  303.645417
# Num_Bank_Accounts         150000.0    17.006940   117.069476   -1.000000
# Num_Credit_Card           150000.0    22.623447   129.143006    0.000000
# Interest_Rate             150000.0    71.234907   461.537193    1.000000
# Delay_from_due_date       150000.0    21.063400    14.860154   -5.000000
# Num_Credit_Inquiries      147000.0    28.529014   194.456058    0.000000
# Credit_Utilization_Ratio  150000.0    32.283309     5.113315   20.000000
# Total_EMI_per_month       150000.0  1432.513579  8403.759977    0.000000
#
#                                   25%          50%          75%           max
# Monthly_Inhand_Salary     1625.265833  3091.000000  5948.454596  15204.633333
# Num_Bank_Accounts            3.000000     6.000000     7.000000   1798.000000
# Num_Credit_Card              4.000000     5.000000     7.000000   1499.000000
# Interest_Rate                8.000000    13.000000    20.000000   5799.000000
# Delay_from_due_date         10.000000    18.000000    28.000000     67.000000
# Num_Credit_Inquiries         3.000000     6.000000     9.000000   2597.000000
# Credit_Utilization_Ratio    28.054731    32.297058    36.487954     50.000000
# Total_EMI_per_month         30.947775    71.280006   166.279555  82398.000000

# %% [markdown]
#                                                       ** cleaning the age column**
#
#
# ---

# %%
df_full['Age'] = df_full['Age'].map(lambda x: str(x).strip('_ ,"'))

# %%
df_full['Age'] = df_full['Age'].astype('int64')

# %%
df_full['Age'].dtypes
# Out:
# dtype('int64')

# %%
#calculate the min and max mode: which is the min value that appears most often. and the max too

import scipy.stats as stats 
list_of_ages = df_full.groupby('Customer_ID')['Age'].apply(list)
x, y = list_of_ages.apply(lambda x: stats.mode(x)).apply([min, max])
mini, maxi = x[0][0], y[0][0]
# Out:
# <ipython-input-224-371bd24316dd>:5: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   x, y = list_of_ages.apply(lambda x: stats.mode(x)).apply([min, max])

# %%
#create a temp column and assign NaN to every value less than 14 or bigger than 56
temp_age_column = df_full['Age'].transform(lambda x: np.NaN if ((x<mini)|(x>maxi)) else x)

# %%
# df_full.groupby('Customer_ID')['Age'].describe()
#df_full.groupby('Customer_ID')['Age'].apply(print)

# %%
# fill the all the ages of each customer ID with the local mode for all values, if its empty then fill it with NaN
mode_by_group = df_full.groupby('Customer_ID')['Age'].transform(lambda x: x.mode()[0] if not x.mode().empty else np.NaN)
result = temp_age_column.fillna(mode_by_group)

# %%
df_full['Age']=result

# %%
counts =df_full['Month'].value_counts()
counts
# Out:
# January      12500
# February     12500
# March        12500
# April        12500
# May          12500
# June         12500
# July         12500
# August       12500
# September    12500
# October      12500
# November     12500
# December     12500
# Name: Month, dtype: int64

# %% [markdown]
# check if the occupation needs cleaning

# %%
Occupation =df_full['Occupation'].value_counts()
Occupation
# Out:
# _______          10500
# Lawyer            9899
# Engineer          9562
# Architect         9550
# Mechanic          9459
# Accountant        9404
# Scientist         9403
# Developer         9381
# Media_Manager     9362
# Teacher           9318
# Entrepreneur      9277
# Journalist        9122
# Doctor            9114
# Manager           8973
# Musician          8858
# Writer            8818
# Name: Occupation, dtype: int64

# %%
df_full['Occupation'] = df_full['Occupation'].map(lambda x: str(x).strip('_'))

# %%
df_full['Occupation'] = df_full.groupby('Customer_ID')['Occupation'].transform(lambda x: x.mode()[0])

# %%
Occupation =df_full['Occupation'].value_counts()
Occupation
# Out:
# Lawyer           10644
# Engineer         10296
# Architect        10236
# Mechanic         10164
# Scientist        10116
# Accountant       10116
# Developer        10080
# Media_Manager    10068
# Teacher          10008
# Entrepreneur      9972
# Doctor            9852
# Journalist        9804
# Manager           9648
# Musician          9528
# Writer            9456
# unkown              12
# Name: Occupation, dtype: int64

# %%
check = df_full[df_full['Occupation'] == 'Unkown']
check
# Out:
#        Customer_ID      Month   Age Occupation Annual_Income  \
# 93280   CUS_0x9e67    January  24.0     Unkown      44393.86
# 93281   CUS_0x9e67   February  24.0     Unkown      44393.86
# 93282   CUS_0x9e67      March  24.0     Unkown     44393.86_
# 93283   CUS_0x9e67      April  24.0     Unkown      44393.86
# 93284   CUS_0x9e67        May  24.0     Unkown      44393.86
# 93285   CUS_0x9e67       June  24.0     Unkown      44393.86
# 93286   CUS_0x9e67       July  24.0     Unkown      44393.86
# 93287   CUS_0x9e67     August  25.0     Unkown      44393.86
# 146640  CUS_0x9e67  September  25.0     Unkown      44393.86
# 146641  CUS_0x9e67    October  25.0     Unkown      44393.86
# 146642  CUS_0x9e67   November  25.0     Unkown      44393.86
# 146643  CUS_0x9e67   December  25.0     Unkown      44393.86
#
#         Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 93280             3504.488333                  6                3
# 93281                     NaN                  6                3
# 93282             3504.488333                  6                3
# 93283             3504.488333                  6                3
# 93284             3504.488333                  6                3
# 93285                     NaN                  6                3
# 93286             3504.488333                  6                3
# 93287             3504.488333                  6                3
# 146640            3504.488333                  6                3
# 146641                    NaN                  6                3
# 146642            3504.488333                  6                3
# 146643            3504.488333                  6                3
#
#         Interest_Rate Num_of_Loan                   Type_of_Loan  \
# 93280              12           2  Student Loan, and Payday Loan
# 93281              12           2  Student Loan, and Payday Loan
# 93282              12           2  Student Loan, and Payday Loan
# 93283              12           2  Student Loan, and Payday Loan
# 93284              12           2  Student Loan, and Payday Loan
# 93285              12           2  Student Loan, and Payday Loan
# 93286              12           2  Student Loan, and Payday Loan
# 93287              12           2  Student Loan, and Payday Loan
# 146640             12           2  Student Loan, and Payday Loan
# 146641             12           2  Student Loan, and Payday Loan
# 146642             12           2  Student Loan, and Payday Loan
# 146643             12           2  Student Loan, and Payday Loan
#
#         Delay_from_due_date Num_of_Delayed_Payment Changed_Credit_Limit  \
# 93280                    11                      9                10.74
# 93281                    15                     11                10.74
# 93282                    15                     11                10.74
# 93283                    15                     13                    _
# 93284                    19                     11                10.74
# 93285                    15                      9                    _
# 93286                    19                     11                10.74
# 93287                    15                     11                12.74
# 146640                   20                     11   17.740000000000006
# 146641                   17                      8                10.74
# 146642                   15                     11                10.74
# 146643                   20                    NaN                10.74
#
#         Num_Credit_Inquiries Credit_Mix Outstanding_Debt  \
# 93280                    NaN          _          1270.97
# 93281                    3.0   Standard          1270.97
# 93282                    3.0          _          1270.97
# 93283                    3.0          _          1270.97
# 93284                    3.0   Standard          1270.97
# 93285                    3.0          _          1270.97
# 93286                    3.0   Standard          1270.97
# 93287                 2170.0   Standard          1270.97
# 146640                   3.0   Standard          1270.97
# 146641                   3.0   Standard          1270.97
# 146642                   3.0   Standard          1270.97
# 146643                   3.0   Standard          1270.97
#
#         Credit_Utilization_Ratio      Credit_History_Age  \
# 93280                  37.328326                     NaN
# 93281                  38.288971   20 Years and 4 Months
# 93282                  29.115904   20 Years and 5 Months
# 93283                  27.476836                     NaN
# 93284                  25.366794   20 Years and 7 Months
# 93285                  39.860247   20 Years and 8 Months
# 93286                  33.895918   20 Years and 9 Months
# 93287                  30.145633  20 Years and 10 Months
# 146640                 36.337700  20 Years and 11 Months
# 146641                 33.036891   21 Years and 0 Months
# 146642                 39.955066   21 Years and 1 Months
# 146643                 25.636973   21 Years and 2 Months
#
#        Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 93280                    Yes            63.794335       91.47043380118635
# 93281                    Yes            63.794335       48.74251133681211
# 93282                    Yes            63.794335       73.10076082927787
# 93283                    Yes            63.794335       218.8494789557392
# 93284                    Yes            63.794335      129.96478872285044
# 93285                    Yes            63.794335      182.15844474347492
# 93286                    Yes            63.794335      430.17172880535406
# 93287                    Yes            63.794335       73.09873138982826
# 146640                   Yes            63.794335      140.81296985998722
# 146641                   Yes            63.794335      61.836087951126025
# 146642                   Yes            63.794335       221.2671924149934
# 146643                   Yes            63.794335      111.43029650866764
#
#                        Payment_Behaviour     Monthly_Balance Credit_Score
# 93280   High_spent_Medium_value_payments   445.1840640677529     Standard
# 93281    High_spent_Large_value_payments   477.9119865321272     Standard
# 93282   High_spent_Medium_value_payments   463.5537370396614     Standard
# 93283     Low_spent_Small_value_payments   357.8050189132002     Standard
# 93284     Low_spent_Large_value_payments   426.6897091460888         Poor
# 93285    High_spent_Small_value_payments   364.4960531254644     Standard
# 93286     Low_spent_Small_value_payments  146.48276906358524         Poor
# 93287   High_spent_Medium_value_payments  463.55576647911107         Poor
# 146640    Low_spent_Small_value_payments   435.8415280089521          NaN
# 146641   High_spent_Small_value_payments  484.81840991781326          NaN
# 146642    Low_spent_Small_value_payments  355.38730545394594          NaN
# 146643  High_spent_Medium_value_payments   425.2242013602717          NaN

# %%
df_full['Occupation'].replace('', 'Unkown', inplace=True)

# %%
Occupation =df_full['Occupation'].value_counts()
Occupation
# Out:
# Lawyer           10644
# Engineer         10296
# Architect        10236
# Mechanic         10164
# Scientist        10116
# Accountant       10116
# Developer        10080
# Media_Manager    10068
# Teacher          10008
# Entrepreneur      9972
# Doctor            9852
# Journalist        9804
# Manager           9648
# Musician          9528
# Writer            9456
# Unkown              12
# Name: Occupation, dtype: int64
